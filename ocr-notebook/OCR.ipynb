# %%
# !pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached torch-2.7.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.22.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached scipy-1.15.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached scikit_image-0.25.2-cp313-cp313-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached python_bidi-0.6.6-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached shapely-2.1.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached pyclipper-1.3.0.post6-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached ninja-1.11.1.4-py3-none-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# ...

# %%
import matplotlib.pyplot as plt
import cv2
import easyocr
from IPython.display import Image

# %%
Image("C:\Dip_project\plates\scaned_img_0.jpg")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Tiyasha Ghosh\AppData\Local\Temp\ipykernel_18660\1773230194.py:1: SyntaxWarning: invalid escape sequence '\D'
#   Image("C:\Dip_project\plates\scaned_img_0.jpg")

# %%
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
output = reader.readtext("C:\Dip_project\plates\scaned_img_0.jpg")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Tiyasha Ghosh\AppData\Local\Temp\ipykernel_18660\1879424553.py:1: SyntaxWarning: invalid escape sequence '\D'
#   output = reader.readtext("C:\Dip_project\plates\scaned_img_0.jpg")
# C:\Users\Tiyasha Ghosh\anaconda3\envs\license\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
output
# Out:
# [([[np.int32(61), np.int32(29)],
#    [np.int32(279), np.int32(29)],
#    [np.int32(279), np.int32(89)],
#    [np.int32(61), np.int32(89)]],
#   '22 BH 6517 A',
#   np.float64(0.7890799444146562))]
